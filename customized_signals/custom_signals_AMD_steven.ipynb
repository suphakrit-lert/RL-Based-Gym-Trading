# %% [markdown]
# # 0. Install and Import dependencies

# %%
# !pip install tensorflow-gpu==1.15.0 tensorflow==1.15.0 stable-baselines gym-anytrading gym

# %%
# Gym stuff
import gymnasium as gym
import gym_anytrading

# Stable baselines - rl stuff
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import A2C

# Processing libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import quantstats as qs

# %%
# Specify parameters
STOCK_NAME = 'AMD'

# Window size for training
TRAIN_WINDOW_SIZE = 10
TRAIN_START = '2023-01-01'
TRAIN_END = '2023-12-31'

TEST_WINDOW_SIZE = 10

# Indicator parameters
SMA_PERIOD = 10

# %% [markdown]
# # 1. Get Data

# %%
import yfinance as yf

df = yf.Ticker(STOCK_NAME)
df = df.history(period="max")
df = df.loc[TRAIN_START:, ['Open', 'High', 'Low', 'Close', 'Volume']]
print(df.shape)
df.head()
# Out:
# (340, 5)
#                                 Open       High        Low      Close  \
# Date
# 2023-01-03 00:00:00-05:00  66.000000  66.879997  63.590000  64.019997
# 2023-01-04 00:00:00-05:00  65.000000  65.790001  63.310001  64.660004
# 2023-01-05 00:00:00-05:00  64.150002  64.349998  62.299999  62.330002
# 2023-01-06 00:00:00-05:00  63.150002  64.300003  60.049999  63.959999
# 2023-01-09 00:00:00-05:00  66.220001  69.320000  65.669998  67.239998
#
#                              Volume
# Date
# 2023-01-03 00:00:00-05:00  46851800
# 2023-01-04 00:00:00-05:00  47477100
# 2023-01-05 00:00:00-05:00  46159500
# 2023-01-06 00:00:00-05:00  70161300
# 2023-01-09 00:00:00-05:00  69741300

# %%
TRAIN_ENV_FRAME_BOUND = (TRAIN_WINDOW_SIZE, df[TRAIN_START:TRAIN_END].shape[0])
TEST_ENV_FRAME_BOUND = (df[TRAIN_START:TRAIN_END].shape[0], df.shape[0])

# %%
TRAIN_ENV_FRAME_BOUND
# Out:
# (10, 250)

# %%
TEST_ENV_FRAME_BOUND
# Out:
# (250, 340)

# %%
df[TRAIN_START:TRAIN_END]
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-01-03 00:00:00-05:00   66.000000   66.879997   63.590000   64.019997
# 2023-01-04 00:00:00-05:00   65.000000   65.790001   63.310001   64.660004
# 2023-01-05 00:00:00-05:00   64.150002   64.349998   62.299999   62.330002
# 2023-01-06 00:00:00-05:00   63.150002   64.300003   60.049999   63.959999
# 2023-01-09 00:00:00-05:00   66.220001   69.320000   65.669998   67.239998
# ...                               ...         ...         ...         ...
# 2023-12-22 00:00:00-05:00  140.479996  140.699997  138.309998  139.600006
# 2023-12-26 00:00:00-05:00  140.070007  143.850006  139.919998  143.410004
# 2023-12-27 00:00:00-05:00  144.720001  146.250000  143.179993  146.070007
# 2023-12-28 00:00:00-05:00  146.800003  150.410004  145.949997  148.759995
# 2023-12-29 00:00:00-05:00  149.500000  151.050003  147.199997  147.410004
#
#                              Volume
# Date
# 2023-01-03 00:00:00-05:00  46851800
# 2023-01-04 00:00:00-05:00  47477100
# 2023-01-05 00:00:00-05:00  46159500
# 2023-01-06 00:00:00-05:00  70161300
# 2023-01-09 00:00:00-05:00  69741300
# ...                             ...
# 2023-12-22 00:00:00-05:00  35370400
# 2023-12-26 00:00:00-05:00  47157400
# 2023-12-27 00:00:00-05:00  49033400
# 2023-12-28 00:00:00-05:00  63800700
# 2023-12-29 00:00:00-05:00  62028200
#
# [250 rows x 5 columns]

# %% [markdown]
# # 2.1 Add Custom Indicators

# %% [markdown]
# ## 2.1.3. Calculate SMA, RSI and OBV

# %%
from gym_anytrading.envs import StocksEnv
from finta import TA

# %%
df['SMA'] = TA.SMA(df, SMA_PERIOD)
df['RSI'] = TA.RSI(df)
df['OBV'] = TA.OBV(df)
df.fillna(0, inplace=True)

# %% [markdown]
# ## 2.1.4. Create New Environments

# %%
def add_signals(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:, 'Low'].to_numpy()[start:end]
    signal_features = env.df.loc[:, ['Low', 'Volume','SMA', 'RSI', 'OBV']].to_numpy()[start:end]
    return prices, signal_features

# %%
class MyCustomEnv(StocksEnv):
    _process_data = add_signals

# %% [markdown]
# # 3. Build Environment and Train

# %%
env2 = MyCustomEnv(df=df, frame_bound=TRAIN_ENV_FRAME_BOUND, window_size=TRAIN_WINDOW_SIZE)
env_maker = lambda: env2
env = DummyVecEnv([env_maker])

# %%
# model = A2C('MlpPolicy', env, verbose=0) 
# model.learn(total_timesteps=10000)

# %%
from sb3_contrib import RecurrentPPO

model = RecurrentPPO("MlpLstmPolicy", env, verbose=0, seed=2023)
model.learn(total_timesteps=50)

# %% [markdown]
# # 4. Evaluation

# %%
env = MyCustomEnv(df=df, frame_bound=TEST_ENV_FRAME_BOUND, window_size=TEST_WINDOW_SIZE)
observation, info = env.reset()
while True: 
    observation = observation.reshape(TRAIN_WINDOW_SIZE, env2.signal_features.shape[1]) 
    observation = observation[np.newaxis, ...]
    action, _states = model.predict(observation)
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    if done:
        print("info", info)
        break
# Out:
# info {'total_reward': -0.1800689697265625, 'total_profit': 0.758409381313743, 'position': <Positions.Long: 1>}

# %%
observation.shape
# Out:
# (10, 5)

# %%
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()

# %% [markdown]
# # 5. QuantStats

# %%
qs.extend_pandas()

net_worth = pd.Series(env.unwrapped.history['total_profit'], index=df.index[TEST_ENV_FRAME_BOUND[0] + 1:TEST_ENV_FRAME_BOUND[1]])
returns = net_worth.pct_change().iloc[1:]

qs.reports.full(returns)
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2024-01-04
# End Period                 2024-05-09
# Risk-Free Rate             0.0%
# Time in Market             21.0%
#
# Cumulative Return          -24.16%
# CAGR﹪                     -42.48%
#
# Sharpe                     -2.05
# Prob. Sharpe Ratio         7.84%
# Smart Sharpe               -2.02
# Sortino                    -2.29
# Smart Sortino              -2.26
# Sortino/√2                 -1.62
# Smart Sortino/√2           -1.6
# Omega                      0.43
#
# Max Drawdown               -33.01%
# Longest DD Days            93
# Volatility (ann.)          35.44%
# Calmar                     -1.29
# Skew                       -2.64
# Kurtosis                   15.98
#
# Expected Daily %           -0.31%
# Expected Monthly %         -5.38%
# Expected Yearly %          -24.16%
# Kelly Criterion            -51.48%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -3.96%
# Expected Shortfall (cVaR)  -3.96%
#
# Max Consecutive Wins       1
# Max Consecutive Losses     1
# Gain/Pain Ratio            -0.57
# Gain/Pain (1M)             -0.67
#
# Payoff Ratio               0.68
# Profit Factor              0.43
# Common Sense Ratio         0.18
# CPC Index                  0.11
# Tail Ratio                 0.42
# Outlier Win Ratio          15.11
# Outlier Loss Ratio         2.84
#
# MTD                        -12.28%
# 3M                         -29.48%
# 6M                         -24.16%
# YTD                        -24.16%
# 1Y                         -24.16%
# 3Y (ann.)                  -42.48%
# 5Y (ann.)                  -42.48%
# 10Y (ann.)                 -42.48%
# All-time (ann.)            -42.48%
#
# Best Day                   8.01%
# Worst Day                  -11.58%
# Best Month                 13.2%
# Worst Month                -12.28%
# Best Year                  -24.16%
# Worst Year                 -24.16%
#
# Avg. Drawdown              -33.01%
# Avg. Drawdown Days         93
# Recovery Factor            0.77
# Ulcer Index                0.14
# Serenity Index             -0.16
#
# Avg. Up Month              13.2%
# Avg. Down Month            -9.46%
# Win Days %                 38.89%
# Win Month %                20.0%
# Win Quarter %              0.0%
# Win Year %                 0.0%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2024-02-07  2024-05-09  2024-05-09    92    -33.005156        -32.466743
# <h4>Strategy Visualization</h4>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 6
#       3 net_worth = pd.Series(env.unwrapped.history['total_profit'], index=df.index[TEST_ENV_FRAME_BOUND[0] + 1:TEST_ENV_FRAME_BOUND[1]])
#       4 returns = net_worth.pct_change().iloc[1:]
# ----> 6 qs.reports.full(returns)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\quantstats\reports.py:628, in full(returns, benchmark, rf, grayscale, figsize, display, compounded, periods_per_year, match_dates, **kwargs)
#     625     print("\n\n")
#     626     print("[Strategy Visualization]\nvia Matplotlib")
# --> 628 plots(
#     629     returns=returns,
#     630     benchmark=benchmark,
#     631     grayscale=grayscale,
#     632     figsize=figsize,
#     633     mode="full",
#     634     periods_per_year=periods_per_year,
#     635     prepare_returns=False,
#     636     benchmark_title=benchmark_title,
#     637     strategy_title=strategy_title,
#     638     active=active,
#     639 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\quantstats\reports.py:1368, in plots(returns, benchmark, grayscale, figsize, mode, compounded, periods_per_year, prepare_returns, match_dates, **kwargs)
#    1355 if benchmark is not None:
#    1356     _plots.rolling_beta(
#    1357         returns,
#    1358         benchmark,
#    (...)
#    1365         prepare_returns=False,
#    1366     )
# -> 1368 _plots.rolling_volatility(
#    1369     returns,
#    1370     benchmark,
#    1371     grayscale=grayscale,
#    1372     figsize=small_fig_size,
#    1373     show=True,
#    1374     ylabel=False,
#    1375     period=win_half_year,
#    1376 )
#    1378 _plots.rolling_sharpe(
#    1379     returns,
#    1380     grayscale=grayscale,
#    (...)
#    1384     period=win_half_year,
#    1385 )
#    1387 _plots.rolling_sortino(
#    1388     returns,
#    1389     grayscale=grayscale,
#    (...)
#    1393     period=win_half_year,
#    1394 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\quantstats\_plotting\wrappers.py:821, in rolling_volatility(returns, benchmark, period, period_label, periods_per_year, lw, fontname, grayscale, figsize, ylabel, subtitle, savefig, show)
#     816     benchmark = _utils._prepare_benchmark(benchmark, returns.index)
#     817     benchmark = _stats.rolling_volatility(
#     818         benchmark, period, periods_per_year, prepare_returns=False
#     819     )
# --> 821 fig = _core.plot_rolling_stats(
#     822     returns,
#     823     benchmark,
#     824     hline=returns.mean(),
#     825     hlw=1.5,
#     826     ylabel=ylabel,
#     827     title="Rolling Volatility (%s)" % period_label,
#     828     fontname=fontname,
#     829     grayscale=grayscale,
#     830     lw=lw,
#     831     figsize=figsize,
#     832     subtitle=subtitle,
#     833     savefig=savefig,
#     834     show=show,
#     835 )
#     836 if not show:
#     837     return fig
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\quantstats\_plotting\core.py:676, in plot_rolling_stats(returns, benchmark, title, returns_label, hline, hlw, hlcolor, hllabel, lw, figsize, ylabel, grayscale, fontname, subtitle, savefig, show)
#     668 fig.suptitle(
#     669     title, y=0.94, fontweight="bold", fontname=fontname, fontsize=14, color="black"
#     670 )
#     672 if subtitle:
#     673     ax.set_title(
#     674         "%s - %s           \n"
#     675         % (
# --> 676             df.index.date[:1][0].strftime("%e %b '%y"),
#     677             df.index.date[-1:][0].strftime("%e %b '%y"),
#     678         ),
#     679         fontsize=12,
#     680         color="gray",
#     681     )
#     683 if hline is not None:
#     684     if not isinstance(hline, _pd.Series):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
qs.reports.html(returns, output="quantstats-amd.html")
# Out:
# c:\Users\supha\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.prod with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\supha\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.prod with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\supha\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.prod with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
